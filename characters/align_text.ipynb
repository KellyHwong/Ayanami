# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# @Date    : Mar-01-21 19:58
# @Author  : Kelly Hwong (dianhuangkan@gmail.com)

import os
import yaml
import numpy as np
import pandas

# %%
# pandas 读取 csv
folder = "./Ayanami-Voice-Text"

csv_file = os.path.join(folder, "metadata_cn.csv")
csv_content = pandas.read_csv(csv_file, delimiter='|')

csv_file = os.path.join(folder, "metadata_jp.csv")
csv_content_jp = pandas.read_csv(csv_file, delimiter='|')

# %%
scenarios = list(set(csv_content["prefix"]))
scenarios
# Out:
# ['新岁之鬼神',
#  '冷静偶像·迷惑中',
#  '【Live2D】黯然礼服',
#  '【动漫特典】特殊潜入作战披风',
#  '新年的愿望',
#  'ニコニコ',
#  '【肯德基联动】可乐，加上努力？',
#  '台词',
#  '待宵的魔女',
#  '【动漫特典】微速战斗姿势',
#  '跃动飞踢！',
#  '苍墨武鉴',
#  '乐队型鬼神',
#  '改造',
#  '一式水手风制服',
#  '【誓约】鬼神之华裳']

# %%
list(set(csv_content_jp["prefix"]))
# Out:
# ['微速戦闘姿勢 ボイス一覧',
#  'おませアイドル・困惑中 ボイス一覧',
#  'コーラに努力を添えて ボイス一覧',
#  '宵闇待ちの魔女 ボイス一覧',
#  'デフォルトボイス一覧',
#  '特殊潜入作戦雨覆 ボイス一覧',
#  '改造後ボイス',
#  '年越しの鼓動 ボイス一覧',
#  'ニコニコ ボイス一覧',
#  'ROCK’n KIJIN ボイス一覧',
#  '波濤新歳 ボイス一覧',
#  'ケッコン後(鬼神華裳)ボイス',
#  '闇然礼装 ボイス一覧',
#  'Navalistic Showdown ボイス一覧',
#  'ダイナミック・キックオフ ボイス一覧']

# %%
def build_dict(values):
    # values: numpy array of a DataFrame
    d = {}
    for row in values:
        v = None if row[1] == "None" else row[1]
        if row[0] not in d:
            d[row[0]] = [v]
        else:
            d[row[0]].append(v)
        
        # 触摸 -> タッチ
        # or 触摸 -> [タッチ, タッチ1]

    return d

# %%
yaml_file = os.path.join(folder, "alignment/align_prefix.yml")
with open(yaml_file, 'r', encoding="utf-8") as f:
    data = yaml.safe_load(f)
d_prefix = data["prefix"]
d_prefix
# Out:
# {'改造': '改造後ボイス',
#  'ニコニコ': 'ニコニコ ボイス一覧',
#  '新年的愿望': '年越しの鼓動 ボイス一覧',
#  '【誓约】鬼神之华裳': 'ケッコン後(鬼神華裳)ボイス',
#  '【肯德基联动】可乐，加上努力？': 'コーラに努力を添えて ボイス一覧',
#  '台词': 'デフォルトボイス一覧',
#  '一式水手风制服': 'None',
#  '新岁之鬼神': '波濤新歳 ボイス一覧',
#  '苍墨武鉴': 'Navalistic Showdown ボイス一覧',
#  '【动漫特典】微速战斗姿势': '微速戦闘姿勢 ボイス一覧',
#  '跃动飞踢！': 'ダイナミック・キックオフ ボイス一覧',
#  '乐队型鬼神': 'ROCK’n KIJIN ボイス一覧',
#  '【动漫特典】特殊潜入作战披风': '特殊潜入作戦雨覆 ボイス一覧',
#  '待宵的魔女': '宵闇待ちの魔女 ボイス一覧',
#  '冷静偶像·迷惑中': 'おませアイドル・困惑中 ボイス一覧',
#  '【Live2D】黯然礼服': '闇然礼装 ボイス一覧'}

# %%
yaml_file = os.path.join(folder, "alignment/align_scenario.yml")
with open(yaml_file, 'r', encoding="utf-8") as f:
    data = yaml.safe_load(f)
d_scenario = data["scenario"]
d_scenario
# Out:
# {'登录': 'ログイン',
#  '登录欢迎': 'None',
#  '主界面': ['メイン', 'メイン1', 'メイン2', 'メイン3'],
#  '主界面1': 'メイン1',
#  '主界面2': 'メイン2',
#  '主界面3': 'メイン3',
#  '主界面4': 'メイン4',
#  '触摸': ['タッチ', 'タッチ1'],
#  '特殊触摸': 'タッチ2',
#  '摸头': 'タッチ3',
#  '技能': 'スキル',
#  '好感度-失望': '失望',
#  '誓约': 'ケッコン',
#  '好感度-陌生': '知り合い',
#  '旗舰开战': '戦闘開始',
#  '任务完成': '任務完了',
#  '好感度-爱': 'ラブ',
#  '胜利MVP': '勝利',
#  '任务提醒': '任務',
#  '好感度-友好': '友好',
#  '获得': '入手時',
#  '查看详情': '詳細確認',
#  '回港': '母港帰還',
#  '失败': '失敗',
#  '强化成功': '強化成功',
#  '好感度-喜欢': '好き',
#  '彩蛋（拉菲，标枪，Z23的任意两艘）': 'ラフィー、ジャベリン、Z23の内2人と編成',
#  '彩蛋（拉菲）': 'ラフィーと編成',
#  '彩蛋（长岛）': 'ロング・アイランドと編成',
#  '彩蛋（祥凤）': '祥鳳と編成',
#  '委托完成': '委託完了',
#  '简介': 'None',
#  '邮件提醒': 'メール',
#  'HP告急': '損傷大'}

# %%
# Open two csv files, and check by CN metadata
data_cn = pandas.read_csv(os.path.join(folder, "metadata_cn.csv"), delimiter='|')
data_jp = pandas.read_csv(os.path.join(folder, "metadata_jp.csv"), delimiter='|')

# %%
data_cn.columns
# Out:
# Index(['prefix', 'scenario', 'dialogue', 'filename', 'url'], dtype='object')

# %%
data_jp.columns
# Out:
# Index(['prefix', 'scenario', 'dialogue'], dtype='object')

# %%
d_prefix
# Out:
# {'改造': '改造後ボイス',
#  'ニコニコ': 'ニコニコ ボイス一覧',
#  '新年的愿望': '年越しの鼓動 ボイス一覧',
#  '【誓约】鬼神之华裳': 'ケッコン後(鬼神華裳)ボイス',
#  '【肯德基联动】可乐，加上努力？': 'コーラに努力を添えて ボイス一覧',
#  '台词': 'デフォルトボイス一覧',
#  '一式水手风制服': 'None',
#  '新岁之鬼神': '波濤新歳 ボイス一覧',
#  '苍墨武鉴': 'Navalistic Showdown ボイス一覧',
#  '【动漫特典】微速战斗姿势': '微速戦闘姿勢 ボイス一覧',
#  '跃动飞踢！': 'ダイナミック・キックオフ ボイス一覧',
#  '乐队型鬼神': 'ROCK’n KIJIN ボイス一覧',
#  '【动漫特典】特殊潜入作战披风': '特殊潜入作戦雨覆 ボイス一覧',
#  '待宵的魔女': '宵闇待ちの魔女 ボイス一覧',
#  '冷静偶像·迷惑中': 'おませアイドル・困惑中 ボイス一覧',
#  '【Live2D】黯然礼服': '闇然礼装 ボイス一覧'}

# %%
_scenario_jp_candidates = d_scenario["获得"]
_scenario_jp_candidates
# Out:
# '入手時'

# %%
# O(N)
prefix_jp, scenario_jp, dialogue_jp = [], [], []
for row in data_cn.values:
    prefix_cn, scenario_cn, _dialogue_jp = row[0], row[1], "None"
    print(f"查询, prefix_cn: {prefix_cn}; scenario_cn: {scenario_cn}")

    # Map prefix_cn to prefix_jp
    _prefix_jp = d_prefix[prefix_cn] # prefix_cn -> prefix_jp 一一对应
    _scenario_jp_candidates = d_scenario[scenario_cn]
    if not isinstance(_scenario_jp_candidates, list):
        _scenario_jp_candidates = [_scenario_jp_candidates]
    if _prefix_jp is not None and _scenario_jp_candidates[0] is not None:
        # _dialogue_jp_df 查询结果
        for _scenario_jp in _scenario_jp_candidates:
            _dialogue_jp_df = data_jp[\
                np.char.equal(data_jp["prefix"].values.astype(str),_prefix_jp) & \
                    np.char.equal(data_jp["scenario"].values.astype(str),_scenario_jp)]
            if _dialogue_jp_df.empty:
                print(f"[Log]CN wiki含有，但JP wiki 不含此 prefix {_prefix_jp}, scenario {_scenario_jp} 下的文本")
            else:
                # got the corresponding JP voice text
                print(
                    f"查询到, prefix_jp: {_prefix_jp}; scenario_jp: {_scenario_jp}")
                # DataFrame to string
                _dialogue_jp = _dialogue_jp_df["dialogue"].values.astype(str)[0]
                continue
    else:
        # _scenario_jp_candidates==[None]
        _scenario_jp = "None"
        print(f"未查询到")

    prefix_jp.append(_prefix_jp)
    scenario_jp.append(_scenario_jp)
    dialogue_jp.append(_dialogue_jp)
# Out:
# 查询, prefix_cn: 台词; scenario_cn: 登录欢迎
# [Log]CN wiki含有，但JP wiki 不含此 prefix デフォルトボイス一覧, scenario None 下的文本
# 查询, prefix_cn: 台词; scenario_cn: 获得
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 台词; scenario_cn: 登录
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: ログイン
# 查询, prefix_cn: 台词; scenario_cn: 查看详情
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 台词; scenario_cn: 主界面1
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 台词; scenario_cn: 主界面2
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 台词; scenario_cn: 主界面3
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 台词; scenario_cn: 触摸
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix デフォルトボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 台词; scenario_cn: 摸头
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: タッチ3
# 查询, prefix_cn: 台词; scenario_cn: 特殊触摸
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: タッチ2
# 查询, prefix_cn: 台词; scenario_cn: 任务提醒
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 任務
# 查询, prefix_cn: 台词; scenario_cn: 任务完成
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 任務完了
# 查询, prefix_cn: 台词; scenario_cn: 邮件提醒
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: メール
# 查询, prefix_cn: 台词; scenario_cn: 回港
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 母港帰還
# 查询, prefix_cn: 台词; scenario_cn: 委托完成
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 委託完了
# 查询, prefix_cn: 台词; scenario_cn: 强化成功
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 強化成功
# 查询, prefix_cn: 台词; scenario_cn: 旗舰开战
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 戦闘開始
# 查询, prefix_cn: 台词; scenario_cn: 胜利MVP
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 勝利
# 查询, prefix_cn: 台词; scenario_cn: 失败
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 失敗
# 查询, prefix_cn: 台词; scenario_cn: 技能
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: スキル
# 查询, prefix_cn: 台词; scenario_cn: HP告急
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 損傷大
# 查询, prefix_cn: 台词; scenario_cn: 彩蛋（拉菲，标枪，Z23的任意两艘）
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: ラフィー、ジャベリン、Z23の内2人と編成
# 查询, prefix_cn: 台词; scenario_cn: 彩蛋（拉菲）
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: ラフィーと編成
# 查询, prefix_cn: 台词; scenario_cn: 彩蛋（长岛）
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: ロング・アイランドと編成
# 查询, prefix_cn: 台词; scenario_cn: 彩蛋（祥凤）
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 祥鳳と編成
# 查询, prefix_cn: 台词; scenario_cn: 简介
# [Log]CN wiki含有，但JP wiki 不含此 prefix デフォルトボイス一覧, scenario None 下的文本
# 查询, prefix_cn: 台词; scenario_cn: 好感度-失望
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 失望
# 查询, prefix_cn: 台词; scenario_cn: 好感度-陌生
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 知り合い
# 查询, prefix_cn: 台词; scenario_cn: 好感度-友好
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 友好
# 查询, prefix_cn: 台词; scenario_cn: 好感度-喜欢
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: 好き
# 查询, prefix_cn: 台词; scenario_cn: 好感度-爱
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: ラブ
# 查询, prefix_cn: 台词; scenario_cn: 誓约
# 查询到, prefix_jp: デフォルトボイス一覧; scenario_jp: ケッコン
# 查询, prefix_cn: 改造; scenario_cn: 获得
# 查询到, prefix_jp: 改造後ボイス; scenario_jp: 入手時
# 查询, prefix_cn: 改造; scenario_cn: 主界面1
# 查询到, prefix_jp: 改造後ボイス; scenario_jp: メイン1
# 查询, prefix_cn: 改造; scenario_cn: 主界面2
# 查询到, prefix_jp: 改造後ボイス; scenario_jp: メイン2
# 查询, prefix_cn: 改造; scenario_cn: 主界面3
# 查询到, prefix_jp: 改造後ボイス; scenario_jp: メイン3
# 查询, prefix_cn: 改造; scenario_cn: 触摸
# 查询到, prefix_jp: 改造後ボイス; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix 改造後ボイス, scenario タッチ1 下的文本
# 查询, prefix_cn: 改造; scenario_cn: 旗舰开战
# 查询到, prefix_jp: 改造後ボイス; scenario_jp: 戦闘開始
# 查询, prefix_cn: 改造; scenario_cn: 胜利MVP
# 查询到, prefix_jp: 改造後ボイス; scenario_jp: 勝利
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 获得
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: 入手時
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 登录
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: ログイン
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 查看详情
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: 詳細確認
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 主界面1
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: メイン1
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 主界面2
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: メイン2
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 触摸
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix ケッコン後(鬼神華裳)ボイス, scenario タッチ1 下的文本
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 特殊触摸
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: タッチ2
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 好感度-爱
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: ラブ
# 查询, prefix_cn: 【誓约】鬼神之华裳; scenario_cn: 胜利MVP
# 查询到, prefix_jp: ケッコン後(鬼神華裳)ボイス; scenario_jp: 勝利
# 查询, prefix_cn: 待宵的魔女; scenario_cn: 获得
# 查询到, prefix_jp: 宵闇待ちの魔女 ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 待宵的魔女; scenario_cn: 主界面1
# 查询到, prefix_jp: 宵闇待ちの魔女 ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 待宵的魔女; scenario_cn: 主界面2
# 查询到, prefix_jp: 宵闇待ちの魔女 ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 待宵的魔女; scenario_cn: 主界面3
# 查询到, prefix_jp: 宵闇待ちの魔女 ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 待宵的魔女; scenario_cn: 触摸
# [Log]CN wiki含有，但JP wiki 不含此 prefix 宵闇待ちの魔女 ボイス一覧, scenario タッチ 下的文本
# 查询到, prefix_jp: 宵闇待ちの魔女 ボイス一覧; scenario_jp: タッチ1
# 查询, prefix_cn: 待宵的魔女; scenario_cn: 特殊触摸
# 查询到, prefix_jp: 宵闇待ちの魔女 ボイス一覧; scenario_jp: タッチ2
# 查询, prefix_cn: ニコニコ; scenario_cn: 获得
# 查询到, prefix_jp: ニコニコ ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 获得
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 登录
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: ログイン
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 查看详情
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 主界面1
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 主界面2
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 主界面3
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 触摸
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix ROCK’n KIJIN ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 任务完成
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: 任務完了
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 委托完成
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: 委託完了
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 旗舰开战
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: 戦闘開始
# 查询, prefix_cn: 乐队型鬼神; scenario_cn: 胜利MVP
# 查询到, prefix_jp: ROCK’n KIJIN ボイス一覧; scenario_jp: 勝利
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 获得
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 登录
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: ログイン
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 查看详情
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 主界面1
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 主界面2
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 主界面3
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 触摸
# [Log]CN wiki含有，但JP wiki 不含此 prefix 波濤新歳 ボイス一覧, scenario タッチ 下的文本
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: タッチ1
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 特殊触摸
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: タッチ2
# 查询, prefix_cn: 新岁之鬼神; scenario_cn: 好感度-爱
# 查询到, prefix_jp: 波濤新歳 ボイス一覧; scenario_jp: ラブ
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 获得
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario 入手時 下的文本
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 登录
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario ログイン 下的文本
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 查看详情
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario 詳細確認 下的文本
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 主界面1
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario メイン1 下的文本
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 主界面2
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario メイン2 下的文本
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 主界面3
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario メイン3 下的文本
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 触摸
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario タッチ 下的文本
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario タッチ1 下的文本
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 回港
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario 母港帰還 下的文本
# 查询, prefix_cn: 一式水手风制服; scenario_cn: 好感度-爱
# [Log]CN wiki含有，但JP wiki 不含此 prefix None, scenario ラブ 下的文本
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 获得
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 登录
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: ログイン
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 查看详情
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 主界面1
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 主界面2
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 主界面3
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 主界面4
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: メイン4
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 触摸
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix おませアイドル・困惑中 ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 回港
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: 母港帰還
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 旗舰开战
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: 戦闘開始
# 查询, prefix_cn: 冷静偶像·迷惑中; scenario_cn: 胜利MVP
# 查询到, prefix_jp: おませアイドル・困惑中 ボイス一覧; scenario_jp: 勝利
# 查询, prefix_cn: 新年的愿望; scenario_cn: 获得
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 新年的愿望; scenario_cn: 登录
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: ログイン
# 查询, prefix_cn: 新年的愿望; scenario_cn: 查看详情
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 新年的愿望; scenario_cn: 主界面1
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 新年的愿望; scenario_cn: 主界面2
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 新年的愿望; scenario_cn: 主界面3
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 新年的愿望; scenario_cn: 主界面4
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: メイン4
# 查询, prefix_cn: 新年的愿望; scenario_cn: 触摸
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix 年越しの鼓動 ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 新年的愿望; scenario_cn: 特殊触摸
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: タッチ2
# 查询, prefix_cn: 新年的愿望; scenario_cn: 好感度-爱
# 查询到, prefix_jp: 年越しの鼓動 ボイス一覧; scenario_jp: ラブ
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 获得
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 登录
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: ログイン
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 查看详情
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 主界面1
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 主界面2
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 主界面3
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 主界面4
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: メイン4
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 触摸
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix 特殊潜入作戦雨覆 ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 摸头
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: タッチ3
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 邮件提醒
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: メール
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 强化成功
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: 強化成功
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 旗舰开战
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: 戦闘開始
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 胜利MVP
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: 勝利
# 查询, prefix_cn: 【动漫特典】特殊潜入作战披风; scenario_cn: 失败
# 查询到, prefix_jp: 特殊潜入作戦雨覆 ボイス一覧; scenario_jp: 失敗
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 获得
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 登录
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: ログイン
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 查看详情
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 主界面1
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 主界面2
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 主界面3
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 触摸
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix 闇然礼装 ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 特殊触摸
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: タッチ2
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 旗舰开战
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: 戦闘開始
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 胜利MVP
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: 勝利
# 查询, prefix_cn: 【Live2D】黯然礼服; scenario_cn: 失败
# 查询到, prefix_jp: 闇然礼装 ボイス一覧; scenario_jp: 失敗
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 获得
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 登录
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: ログイン
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 查看详情
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 主界面1
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 主界面2
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 主界面3
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 主界面4
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: メイン4
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 触摸
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix 微速戦闘姿勢 ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 回港
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: 母港帰還
# 查询, prefix_cn: 【动漫特典】微速战斗姿势; scenario_cn: 胜利MVP
# 查询到, prefix_jp: 微速戦闘姿勢 ボイス一覧; scenario_jp: 勝利
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 获得
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 查看详情
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: 詳細確認
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 主界面1
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: メイン1
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 主界面2
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: メイン2
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 主界面3
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: メイン3
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 触摸
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: タッチ
# [Log]CN wiki含有，但JP wiki 不含此 prefix Navalistic Showdown ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 特殊触摸
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: タッチ2
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 任务提醒
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: 任務
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 任务完成
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: 任務完了
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 委托完成
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: 委託完了
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 旗舰开战
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: 戦闘開始
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 胜利MVP
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: 勝利
# 查询, prefix_cn: 苍墨武鉴; scenario_cn: 失败
# 查询到, prefix_jp: Navalistic Showdown ボイス一覧; scenario_jp: 失敗
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 获得
# 查询到, prefix_jp: コーラに努力を添えて ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 登录
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario ログイン 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 查看详情
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario 詳細確認 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 主界面1
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario メイン1 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 主界面2
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario メイン2 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 主界面3
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario メイン3 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 触摸
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario タッチ 下的文本
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 特殊触摸
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario タッチ2 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 任务提醒
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario 任務 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 任务完成
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario 任務完了 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 邮件提醒
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario メール 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 回港
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario 母港帰還 下的文本
# 查询, prefix_cn: 【肯德基联动】可乐，加上努力？; scenario_cn: 委托完成
# [Log]CN wiki含有，但JP wiki 不含此 prefix コーラに努力を添えて ボイス一覧, scenario 委託完了 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 获得
# 查询到, prefix_jp: ダイナミック・キックオフ ボイス一覧; scenario_jp: 入手時
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 登录
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario ログイン 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 查看详情
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario 詳細確認 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 主界面1
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario メイン1 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 主界面2
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario メイン2 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 主界面3
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario メイン3 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 触摸
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario タッチ 下的文本
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario タッチ1 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 特殊触摸
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario タッチ2 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 任务提醒
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario 任務 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 任务完成
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario 任務完了 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 邮件提醒
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario メール 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 回港
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario 母港帰還 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 委托完成
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario 委託完了 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 旗舰开战
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario 戦闘開始 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 胜利MVP
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario 勝利 下的文本
# 查询, prefix_cn: 跃动飞踢！; scenario_cn: 技能
# [Log]CN wiki含有，但JP wiki 不含此 prefix ダイナミック・キックオフ ボイス一覧, scenario スキル 下的文本

# %%
# Append this column
data_cn_to_jp = data_cn.copy()
data_cn_to_jp["prefix_jp"] = prefix_jp
data_cn_to_jp["scenario_jp"] = scenario_jp
data_cn_to_jp["dialogue_jp"] = dialogue_jp
# TODO column "dialogue_jp_norm" 尚未 Normalize, 所以和 doalogue_jp 一樣
data_cn_to_jp["dialogue_jp_norm"] = dialogue_jp

# %%
new_order = ["filename", "dialogue", "dialogue_jp", "prefix", "prefix_jp", "scenario", "scenario_jp"]

# %%
data_cn_to_jp = data_cn_to_jp.reindex(new_order, axis=1)
data_cn_to_jp.to_csv(os.path.join(
    folder, "metadata_aligh.csv"), index=False, sep='|')
data_cn_to_jp[data_cn_to_jp["dialogue_jp"] != "None"].to_csv(os.path.join(
    folder, "metadata.csv"), columns=["filename", "dialogue_jp"], header=False, index=False, sep='|')
